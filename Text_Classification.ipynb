# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinaytechie/Excerl/blob/main/Text_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset=pd.read_csv("/content/sample_data/hate_speech.csv")
dataset.head() # Specifies first 5 rows of datset defautly!
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %%
dataset.shape #number of rows AND columns in the dataset
# Out:
# (5242, 3)

# %%
for index,tweet in enumerate(dataset["tweet"][10:15]):
  print(index+1,"-",tweet)
# Out:
# 1 -  â #ireland consumer price index (mom) climbed from previous 0.2% to 0.5% in may   #blog #silver #gold #forex
# 2 - we are so selfish. #orlando #standwithorlando #pulseshooting #orlandoshooting #biggerproblems #selfish #heabreaking   #values #love #
# 3 - i get to see my daddy today!!   #80days #gettingfed
# 4 - ouch...junior is angryð#got7 #junior #yugyoem   #omg
# 5 - i am thankful for having a paner. #thankful #positive

# %%
import re
def clean_text(text):
  text=re.sub(r"[^a-zA-Z\']",' ',text)
  text=re.sub(r'[^\x00-\x7F]+',' ',text)
  text=text.lower()
  return text
for index,tweet in enumerate(dataset["tweet"][10:15]):
  print(index+1,"-",clean_text(tweet))
# Out:
# 1 -       ireland consumer price index  mom  climbed from previous      to      in may    blog  silver  gold  forex
# 2 - we are so selfish   orlando  standwithorlando  pulseshooting  orlandoshooting  biggerproblems  selfish  heabreaking    values  love
# 3 - i get to see my daddy today        days  gettingfed
# 4 - ouch   junior is angry     got   junior  yugyoem    omg
# 5 - i am thankful for having a paner   thankful  positive

# %%
dataset['clean_text']=dataset.tweet.apply(lambda x:clean_text(x))

# %%
dataset.head(5)
# Out:
#    id  label                                              tweet  \
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
#
#                                           clean_text
# 0    user when a father is dysfunctional and is s...
# 1   user  user thanks for  lyft credit i can't us...
# 2                                bihday your majesty
# 3   model   i love u take with u all the time in ...
# 4             factsguide  society now     motivation

# %% [markdown]
# Feature Engineering

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words=stopwords.words('english')
len(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 179

# %%
stop=stopwords.words('english')
#dataset['clean_text']=dataset['clean_text'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
dataset.head(6)
# Out:
#    id  label                                              tweet  \
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation
# 5   6      0  [2/2] huge fan fare and big talking before the...
#
#                                           clean_text
# 0  user father dysfunctional selfish drags kids d...
# 1  user user thanks lyft credit can't use cause o...
# 2                                     bihday majesty
# 3                        model love u take u time ur
# 4                      factsguide society motivation
# 5  huge fan fare big talking leave chaos pay disp...

# %%
def gen_freq(text):
  word_list=[]
  for word in text.split():
    word_list.extend(word)
  word_freq=pd.Series(word_list).value_counts()
  word_freq=word_freq.drop(stop_words,errors='ignore')
  return word_freq

# %%
def any_neg(words):
  for word in words:
    if word in ['n','no','not','non'] or re.search:
      return 1
    else:
      return 0

# %%
def is_question(words):
  for word in words:
    if word in ['when','what','how','why','who']:
      return 1
    else:
      return 0
